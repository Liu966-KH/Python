# %% [markdown]
# <a href="https://colab.research.google.com/github/ccsoez/Python/blob/master/Ch4/Page85_2%263.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Page85
#
# ##多元練習

# %% [markdown]
# 2.假設我們有三位學生的國文、數學、與自然成績：
#
# ![p85-2.jpg](data:image/jpeg;base64,...)
#
# 請利用重複結構來計算每個人的總成績：(可以自行決定要用一維陣列或二維陣列)

# %%
#首先要將資料建立為陣列：
score_ch = [100,95,89]
score_math = [20,99,73]
score_sc = [85,75,92]
name = ['嘉明', '小美', '阿雄']

#再使用重複結構來計算

# %%
#使用二維陣列的範例*
score = [[100, 20, 85],[95,99,75],[89,73,92]]
name = ['嘉明', '小美', '阿雄']

for i in range(3):
  sum = 0
  for j in range(3):
    sum += score[i][j]
  print(name[i], '總分為', sum, '分')
# Out:
# 嘉明 總分為 205 分
# 小美 總分為 269 分
# 阿雄 總分為 254 分

# %% [markdown]
# 3. 請利用Python寫一支程式，統計下列成績中，不及格（低於60分）以及成績高於90分的人分別有多少，並將統計結果顯示在電腦螢幕上。
#
# ![p85-3.jpg](data:image/jpeg;base64,...)
#
# 例：
#
# ```
# <60分：3個
# >90分：1個
# ```

# %%
grades = [40, 80, 75, 20, 96, 69, 50]
lower_60 = 0
higher_90 = 0
for i in range(7):
    if grades[i] > 90:
        higher_90 = higher_90 + 1
    elif grades[i] < 60:
        lower_60 = lower_60 + 1
print('<60分: ', lower_60, '個')
print('>90分: ', higher_90, '個')
